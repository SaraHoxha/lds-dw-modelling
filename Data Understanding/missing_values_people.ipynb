# %%
#Imports
import pandas as pd

# %%
# Load the csv file
people_df = pd.read_csv('../data/People.csv')

# %%
#Check if there are missing values and how many
print('Missing values per column:')
print(people_df.isna().sum())

# Print columns with missing values
columns_with_missing_values = people_df.columns[people_df.isnull().any()].tolist()
print('\nColumns with missing values:')
print(columns_with_missing_values)
# Out:
# Missing values per column:
# PERSON_ID                     0
# PERSON_TYPE                   0
# RD_NO                         0
# VEHICLE_ID                10696
# CRASH_DATE                    0
# CITY                     143920
# STATE                    141976
# SEX                        7154
# AGE                      160981
# SAFETY_EQUIPMENT           1410
# AIRBAG_DEPLOYED           10452
# EJECTION                   6705
# INJURY_CLASSIFICATION       296
# DRIVER_ACTION            109766
# DRIVER_VISION            109884
# PHYSICAL_CONDITION       109501
# BAC_RESULT               108833
# DAMAGE_CATEGORY               0
# DAMAGE                    74309
# dtype: int64
#
# Columns with missing values:
# ['VEHICLE_ID', 'CITY', 'STATE', 'SEX', 'AGE', 'SAFETY_EQUIPMENT', 'AIRBAG_DEPLOYED', 'EJECTION', 'INJURY_CLASSIFICATION', 'DRIVER_ACTION', 'DRIVER_VISION', 'PHYSICAL_CONDITION', 'BAC_RESULT', 'DAMAGE']

# %%
print('Missing values per column:')
people_df_processed = pd.read_csv('../data/People_Processed.csv')
print(people_df_processed[columns_with_missing_values].isna().sum())
# Out:
# Missing values per column:
# VEHICLE_ID                10372
# CITY                          0
# STATE                    134364
# SEX                           0
# AGE                      161028
# SAFETY_EQUIPMENT              0
# AIRBAG_DEPLOYED               0
# EJECTION                      0
# INJURY_CLASSIFICATION       282
# DRIVER_ACTION            108833
# DRIVER_VISION            108833
# PHYSICAL_CONDITION            0
# BAC_RESULT               108833
# DAMAGE                    74309
# dtype: int64

# %%
#Get value counts for columns with missing values
for col in people_df[columns_with_missing_values]:
    print(people_df[col].value_counts())
    print('------')
# Out:
# VEHICLE_ID
# 332155.0    60
# 366311.0    44
# 162199.0    44
# 25920.0     43
# 412312.0    41
#             ..
# 338497.0     1
# 338458.0     1
# 338463.0     1
# 338516.0     1
# 460661.0     1
# Name: count, Length: 450064, dtype: int64
# ------
# CITY
# CHICAGO           295710
# CICERO              3988
# SKOKIE              3026
# EVANSTON            2586
# BERWYN              2430
#                    ...
# CALUMETE CITY          1
# NIAGARA FALLS          1
# WHITNEY                1
# MOINT PROSPECT         1
# WYNNEWOOD              1
# Name: count, Length: 6877, dtype: int64
# ------
# STATE
# IL    400648
# IN      6318
# XX      2534
# WI      1887
# MI      1635
# FL       958
# CA       765
# TX       762
# OH       757
# IA       585
# GA       491
# MO       475
# MN       454
# NY       409
# WA       316
# TN       309
# AZ       232
# NC       226
# CO       209
# KY       199
# PA       198
# NJ       174
# VA       172
# MA       163
# MD       152
# AL       151
# ID       131
# MS       130
# AR       111
# NB       103
# NV       103
# OK       101
# LA       101
# KS       100
# SC        86
# CT        52
# UT        45
# OR        44
# ND        35
# NM        31
# MT        30
# DC        29
# NH        27
# ME        25
# SD        22
# DE        22
# WV        17
# RI        16
# WY        15
# HI        13
# AK        12
# VT         9
# Name: count, dtype: int64
# ------
# SEX
# M    295868
# F    216090
# X     38153
# U      7300
# Name: count, dtype: int64
# ------
# AGE
# 25.0     11620
# 27.0     11523
# 26.0     11363
# 24.0     11248
# 28.0     10984
#          ...
# 101.0        3
# 104.0        3
# 110.0        2
# 103.0        1
# 106.0        1
# Name: count, Length: 110, dtype: int64
# ------
# SAFETY_EQUIPMENT
# SAFETY BELT USED                   299040
# USAGE UNKNOWN                      234298
# NONE PRESENT                        17022
# CHILD RESTRAINT USED                 6605
# SAFETY BELT NOT USED                 3418
# HELMET USED                          1284
# HELMET NOT USED                      1100
# CHILD RESTRAINT NOT USED              348
# CHILD RESTRAINT USED IMPROPERLY        40
# Name: count, dtype: int64
# ------
# AIRBAG_DEPLOYED
# DID NOT DEPLOY                            374039
# DEPLOYMENT UNKNOWN                        108522
# NOT APPLICABLE                             46405
# DEPLOYED, FRONT                            14013
# DEPLOYED, COMBINATION                       7393
# DEPLOYED, SIDE                              3536
# DEPLOYED OTHER (KNEE, AIR, BELT, ETC.)       205
# Name: count, dtype: int64
# ------
# EJECTION
# NONE                  523008
# UNKNOWN                30784
# TOTALLY EJECTED         2846
# PARTIALLY EJECTED        814
# TRAPPED/EXTRICATED       408
# Name: count, dtype: int64
# ------
# INJURY_CLASSIFICATION
# NO INDICATION OF INJURY     524430
# NONINCAPACITATING INJURY     21334
# REPORTED, NOT EVIDENT        13843
# INCAPACITATING INJURY         4426
# FATAL                          236
# Name: count, dtype: int64
# ------
# DRIVER_ACTION
# NONE                                 171361
# UNKNOWN                               97822
# FAILED TO YIELD                       45427
# OTHER                                 36727
# FOLLOWED TOO CLOSELY                  32432
# IMPROPER BACKING                      15534
# IMPROPER LANE CHANGE                  13214
# IMPROPER TURN                         12291
# IMPROPER PASSING                      10452
# TOO FAST FOR CONDITIONS                7348
# DISREGARDED CONTROL DEVICES            6509
# IMPROPER PARKING                       1858
# WRONG WAY/SIDE                         1531
# CELL PHONE USE OTHER THAN TEXTING       881
# EVADING POLICE VEHICLE                  744
# EMERGENCY VEHICLE ON CALL               369
# TEXTING                                 222
# STOPPED SCHOOL BUS                       63
# LICENSE RESTRICTIONS                     14
# Name: count, dtype: int64
# ------
# DRIVER_VISION
# NOT OBSCURED              262803
# UNKNOWN                   179559
# OTHER                       4893
# MOVING VEHICLES             3111
# PARKED VEHICLES             1705
# WINDSHIELD (WATER/ICE)      1494
# BLINDED - SUNLIGHT           551
# TREES, PLANTS                199
# BUILDINGS                    194
# BLINDED - HEADLIGHTS          53
# HILLCREST                     40
# BLOWING MATERIALS             35
# EMBANKMENT                    31
# SIGNBOARD                     13
# Name: count, dtype: int64
# ------
# PHYSICAL_CONDITION
# NORMAL                310340
# UNKNOWN               136924
# IMPAIRED - ALCOHOL      1995
# REMOVED BY EMS          1714
# OTHER                   1172
# FATIGUED/ASLEEP         1115
# EMOTIONAL                817
# ILLNESS/FAINTED          365
# HAD BEEN DRINKING        360
# IMPAIRED - DRUGS         215
# MEDICATED                 47
# Name: count, dtype: int64
# ------
# BAC_RESULT
# TEST NOT OFFERED                   449263
# TEST REFUSED                         4781
# TEST PERFORMED, RESULTS UNKNOWN      1076
# TEST TAKEN                            612
# Name: count, dtype: int64
# ------
# DAMAGE
# 1410.432965    2
# 5712.752843    2
# 1118.365715    2
# 2899.333791    2
# 2615.095071    2
#               ..
# 908.134319     1
# 1055.386021    1
# 819.338787     1
# 5565.174458    1
# 6589.530915    1
# Name: count, Length: 490243, dtype: int64
# ------

# %%
# Retrieve columns that provide a value containing "Unknown" substring to indicate when the information for that column is not known.
for col in people_df[columns_with_missing_values]:
    if people_df[col].astype(str).str.contains('unknown', case=False, na=False).any():
        print(f'Column name: {col}')
        print('---')
        print(f'{col} value counts')
        print(people_df[col].value_counts())
# Out:
# Column name: CITY
# ---
# CITY value counts
# CITY
# CHICAGO           295710
# CICERO              3988
# SKOKIE              3026
# EVANSTON            2586
# BERWYN              2430
#                    ...
# CALUMETE CITY          1
# NIAGARA FALLS          1
# WHITNEY                1
# MOINT PROSPECT         1
# WYNNEWOOD              1
# Name: count, Length: 6877, dtype: int64
# Column name: SAFETY_EQUIPMENT
# ---
# SAFETY_EQUIPMENT value counts
# SAFETY_EQUIPMENT
# SAFETY BELT USED                   299040
# USAGE UNKNOWN                      234298
# NONE PRESENT                        17022
# CHILD RESTRAINT USED                 6605
# SAFETY BELT NOT USED                 3418
# HELMET USED                          1284
# HELMET NOT USED                      1100
# CHILD RESTRAINT NOT USED              348
# CHILD RESTRAINT USED IMPROPERLY        40
# Name: count, dtype: int64
# Column name: AIRBAG_DEPLOYED
# ---
# AIRBAG_DEPLOYED value counts
# AIRBAG_DEPLOYED
# DID NOT DEPLOY                            374039
# DEPLOYMENT UNKNOWN                        108522
# NOT APPLICABLE                             46405
# DEPLOYED, FRONT                            14013
# DEPLOYED, COMBINATION                       7393
# DEPLOYED, SIDE                              3536
# DEPLOYED OTHER (KNEE, AIR, BELT, ETC.)       205
# Name: count, dtype: int64
# Column name: EJECTION
# ---
# EJECTION value counts
# EJECTION
# NONE                  523008
# UNKNOWN                30784
# TOTALLY EJECTED         2846
# PARTIALLY EJECTED        814
# TRAPPED/EXTRICATED       408
# Name: count, dtype: int64
# Column name: DRIVER_ACTION
# ---
# DRIVER_ACTION value counts
# DRIVER_ACTION
# NONE                                 171361
# UNKNOWN                               97822
# FAILED TO YIELD                       45427
# OTHER                                 36727
# FOLLOWED TOO CLOSELY                  32432
# IMPROPER BACKING                      15534
# IMPROPER LANE CHANGE                  13214
# IMPROPER TURN                         12291
# IMPROPER PASSING                      10452
# TOO FAST FOR CONDITIONS                7348
# DISREGARDED CONTROL DEVICES            6509
# IMPROPER PARKING                       1858
# WRONG WAY/SIDE                         1531
# CELL PHONE USE OTHER THAN TEXTING       881
# EVADING POLICE VEHICLE                  744
# EMERGENCY VEHICLE ON CALL               369
# TEXTING                                 222
# STOPPED SCHOOL BUS                       63
# LICENSE RESTRICTIONS                     14
# Name: count, dtype: int64
# Column name: DRIVER_VISION
# ---
# DRIVER_VISION value counts
# DRIVER_VISION
# NOT OBSCURED              262803
# UNKNOWN                   179559
# OTHER                       4893
# MOVING VEHICLES             3111
# PARKED VEHICLES             1705
# WINDSHIELD (WATER/ICE)      1494
# BLINDED - SUNLIGHT           551
# TREES, PLANTS                199
# BUILDINGS                    194
# BLINDED - HEADLIGHTS          53
# HILLCREST                     40
# BLOWING MATERIALS             35
# EMBANKMENT                    31
# SIGNBOARD                     13
# Name: count, dtype: int64
# Column name: PHYSICAL_CONDITION
# ---
# PHYSICAL_CONDITION value counts
# PHYSICAL_CONDITION
# NORMAL                310340
# UNKNOWN               136924
# IMPAIRED - ALCOHOL      1995
# REMOVED BY EMS          1714
# OTHER                   1172
# FATIGUED/ASLEEP         1115
# EMOTIONAL                817
# ILLNESS/FAINTED          365
# HAD BEEN DRINKING        360
# IMPAIRED - DRUGS         215
# MEDICATED                 47
# Name: count, dtype: int64
# Column name: BAC_RESULT
# ---
# BAC_RESULT value counts
# BAC_RESULT
# TEST NOT OFFERED                   449263
# TEST REFUSED                         4781
# TEST PERFORMED, RESULTS UNKNOWN      1076
# TEST TAKEN                            612
# Name: count, dtype: int64

# %% [markdown]
# 'PEOPLE' columns that provide an 'UNKNOWN' value
# From the columns with missing values:
#
# 1. CITY
# 2. SAFETY_EQUIPMENT
# 3. AIRBAG_DEPLOYED
# 4. EJECTION
# 5. DRIVER_ACTION
# 6. DRIVER_VISION
# 7. PHYSICAL CONDITION
# 8. BAC_RESULT

# %% [markdown]
# ## Queries to explore pairings in columns with missing values

# %%
# Check if there are observations where city is known but state is NaN
print('Count of observations that have the \"CITY\" column filled but not the \"STATE\" column:')
count_rows_without_states= people_df[columns_with_missing_values].query('CITY == CITY and STATE != STATE')[['CITY', 'STATE']].shape[0]
print(count_rows_without_states)
if count_rows_without_states > 0:
    print('First 5 rows that have the \"CITY\" column filled but not the \"STATE\" column:')
    print(people_df[columns_with_missing_values].query('CITY == CITY and STATE != STATE')[['CITY', 'STATE']].head(5))
# Out:
# Count of observations that have the "CITY" column filled but not the "STATE" column:
# 9005
# First 5 rows that have the "CITY" column filled but not the "STATE" column:
#                  CITY STATE
# 727           CHICAGO   NaN
# 755           CHICAGO   NaN
# 757   LAURIER-STATION   NaN
# 996           CHICAGO   NaN
# 1003          CHICAGO   NaN

# %%
# Check if there are observations where state is known but city is NaN
print('Count of observations that have the \"STATE\" column filled but not the \"CITY\" column:')
count_rows_without_cities = people_df[columns_with_missing_values].query('CITY != CITY and STATE == STATE')[['CITY', 'STATE']].shape[0]
print(count_rows_without_cities)
if count_rows_without_cities > 0:
    print('First 5 rows that have the \"STATE\" column filled but not the \"CITY\" column:')
    print(people_df[columns_with_missing_values].query('CITY != CITY and STATE == STATE')[['CITY', 'STATE']].head(5))
# Out:
# Count of observations that have the "STATE" column filled but not the "CITY" column:
# 10949
# First 5 rows that have the "STATE" column filled but not the "CITY" column:
#     CITY STATE
# 39   NaN    IL
# 61   NaN    IL
# 132  NaN    XX
# 199  NaN    IL
# 200  NaN    IL

# %%
# Check if there are observations where the type is "PASSENGER" and ""DRIVER_ACTION" or "DRIVER_VERSION" are filled
print('Count of observations that have the \"PERSON_TYPE\" as "PASSENGER" and the columns  \"DRIVER_ACTION\" or \"DRIVER_VERSION\" filled:')
count_passenger_with_driver_info = people_df.query('PERSON_TYPE == "PASSENGER" and (DRIVER_ACTION == DRIVER_ACTION or DRIVER_VISION == DRIVER_VISION)').shape[0]
print(count_passenger_with_driver_info)
if count_passenger_with_driver_info > 0:
    print(people_df.query('PERSON_TYPE == "PASSENGER" and (DRIVER_ACTION == DRIVER_ACTION or DRIVER_VISION == DRIVER_VISION)').head(5))
# Out:
# Count of observations that have the "PERSON_TYPE" as "PASSENGER" and the columns  "DRIVER_ACTION" or "DRIVER_VERSION" filled:
# 0

# %%
# Check if there are observations where the "AGE" < 10  and "PERSON_TYPE" is "DRIVER" (Anomalies)
print('Count of observations that have the "AGE" < 10 and \"PERSON_TYPE\" as "DRIVER":')
count_age_0 = people_df.query('AGE  < 10 and PERSON_TYPE == "DRIVER"').shape[0]
print(count_age_0)
if count_age_0 > 0:
    print(people_df.query('AGE < 10 and PERSON_TYPE == "DRIVER"')[['AGE', 'PERSON_TYPE']])
# Out:
# Count of observations that have the "AGE" < 10 and "PERSON_TYPE" as "DRIVER":
# 3720
#         AGE PERSON_TYPE
# 334     0.0      DRIVER
# 369     0.0      DRIVER
# 409     0.0      DRIVER
# 447     0.0      DRIVER
# 1020    0.0      DRIVER
# ...     ...         ...
# 562405  0.0      DRIVER
# 562922  0.0      DRIVER
# 563039  0.0      DRIVER
# 563147  0.0      DRIVER
# 563321  0.0      DRIVER
#
# [3720 rows x 2 columns]
