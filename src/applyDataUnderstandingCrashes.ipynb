# %%
import re
from datetime import datetime
import json
import time

# %%
from utils.read import read_csv
from utils.utils import get_api_key, check_if_file_exists_and_create

# %%
from opencage.geocoder import OpenCageGeocode

# %%
crashes_df = read_csv ('../data/Crashes.csv', 'RD_NO')

# %%
crashes_df
# Out:
# {'JC113649': {'RD_NO': 'JC113649',
#   'CRASH_DATE': '01/12/2019 12:01:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/12/2019 12:01:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 734,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'CENTRAL PARK AVE',
#   'BEAT_OF_OCCURRENCE': 1112.0,
#   'NUM_UNITS': 6.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 0,
#   'CRASH_DAY_OF_WEEK': 7,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.894718028,
#   'LONGITUDE': -87.71643911,
#   'LOCATION': 'POINT (-87.716439109795 41.894718028422)'},
#  'JC113627': {'RD_NO': 'JC113627',
#   'CRASH_DATE': '01/11/2019 11:36:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'STOP SIGN/FLASHER',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 11:42:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#   'SEC_CONTRIBUTORY_CAUSE': 'DISREGARDING STOP SIGN',
#   'STREET_NO': 4432,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'LARAMIE AVE',
#   'BEAT_OF_OCCURRENCE': 1623.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 23,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.961557797,
#   'LONGITUDE': -87.757564024,
#   'LOCATION': 'POINT (-87.757564024038 41.961557797444)'},
#  'JC113637': {'RD_NO': 'JC113637',
#   'CRASH_DATE': '01/11/2019 11:31:00 PM',
#   'POSTED_SPEED_LIMIT': 15,
#   'TRAFFIC_CONTROL_DEVICE': 'STOP SIGN/FLASHER',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE OPPOSITE DIRECTION',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/12/2019 12:08:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 5600,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'LAWNDALE AVE',
#   'BEAT_OF_OCCURRENCE': 822.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 23,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.791459914,
#   'LONGITUDE': -87.715907858,
#   'LOCATION': 'POINT (-87.715907858157 41.791459913725)'},
#  'JC113630': {'RD_NO': 'JC113630',
#   'CRASH_DATE': '01/11/2019 11:22:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 11:48:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER LANE USAGE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 4633,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'JACKSON BLVD',
#   'BEAT_OF_OCCURRENCE': 1131.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 23,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.876778736,
#   'LONGITUDE': -87.741694508,
#   'LOCATION': 'POINT (-87.741694507685 41.876778736117)'},
#  'JC113604': {'RD_NO': 'JC113604',
#   'CRASH_DATE': '01/11/2019 11:08:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'UNKNOWN',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 11:38:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 4438,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'MONTROSE AVE',
#   'BEAT_OF_OCCURRENCE': 1722.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 23,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.960920858,
#   'LONGITUDE': -87.739893056,
#   'LOCATION': 'POINT (-87.739893056441 41.960920858153)'},
#  'JC113579': {'RD_NO': 'JC113579',
#   'CRASH_DATE': '01/11/2019 10:45:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 10:45:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER OVERTAKING/PASSING',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 8140,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'EXCHANGE AVE',
#   'BEAT_OF_OCCURRENCE': 422.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 22,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.747015686,
#   'LONGITUDE': -87.552951169,
#   'LOCATION': 'POINT (-87.552951169307 41.74701568596)'},
#  'JC113617': {'RD_NO': 'JC113617',
#   'CRASH_DATE': '01/11/2019 10:28:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 10:28:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'FAILING TO REDUCE SPEED TO AVOID CRASH',
#   'STREET_NO': 4035,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'CICERO AVE',
#   'BEAT_OF_OCCURRENCE': 1722.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 22,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.954508402,
#   'LONGITUDE': -87.74718788,
#   'LOCATION': 'POINT (-87.747187880166 41.954508401874)'},
#  'JC113568': {'RD_NO': 'JC113568',
#   'CRASH_DATE': '01/11/2019 10:16:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE OPPOSITE DIRECTION',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 10:18:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 7201,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'YATES BLVD',
#   'BEAT_OF_OCCURRENCE': 334.0,
#   'NUM_UNITS': 3.0,
#   'MOST_SEVERE_INJURY': 'NONINCAPACITATING INJURY',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 1.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 22,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.764345064,
#   'LONGITUDE': -87.56633931,
#   'LOCATION': 'POINT (-87.566339309792 41.764345063951)'},
#  'JC113569': {'RD_NO': 'JC113569',
#   'CRASH_DATE': '01/11/2019 10:00:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE SAME DIRECTION',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'UNKNOWN',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 10:30:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER OVERTAKING/PASSING',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 8700,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'STONY ISLAND AVE',
#   'BEAT_OF_OCCURRENCE': 412.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 22,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.73682263,
#   'LONGITUDE': -87.58578342,
#   'LOCATION': 'POINT (-87.585783420329 41.736822630157)'},
#  'JC113528': {'RD_NO': 'JC113528',
#   'CRASH_DATE': '01/11/2019 09:35:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 09:37:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'EXCEEDING AUTHORIZED SPEED LIMIT',
#   'SEC_CONTRIBUTORY_CAUSE': 'FAILING TO REDUCE SPEED TO AVOID CRASH',
#   'STREET_NO': 525,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': '95TH ST',
#   'BEAT_OF_OCCURRENCE': 2223.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 4.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 21,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.72143257,
#   'LONGITUDE': -87.637091514,
#   'LOCATION': 'POINT (-87.637091513994 41.72143256963)'},
#  'JC113502': {'RD_NO': 'JC113502',
#   'CRASH_DATE': '01/11/2019 09:10:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'UNKNOWN',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 09:36:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 4229,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'FOSTER AVE',
#   'BEAT_OF_OCCURRENCE': 1712.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 21,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.97535798,
#   'LONGITUDE': -87.734335949,
#   'LOCATION': 'POINT (-87.734335949372 41.975357979514)'},
#  'JC113476': {'RD_NO': 'JC113476',
#   'CRASH_DATE': '01/11/2019 08:40:00 PM',
#   'POSTED_SPEED_LIMIT': 40,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 08:46:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'EQUIPMENT - VEHICLE CONDITION',
#   'SEC_CONTRIBUTORY_CAUSE': 'EQUIPMENT - VEHICLE CONDITION',
#   'STREET_NO': 5521,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'DEVON AVE',
#   'BEAT_OF_OCCURRENCE': 1621.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 20,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.997196148,
#   'LONGITUDE': -87.766632847,
#   'LOCATION': 'POINT (-87.766632847015 41.997196147514)'},
#  'JC113468': {'RD_NO': 'JC113468',
#   'CRASH_DATE': '01/11/2019 08:40:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 08:41:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER TURNING/NO SIGNAL',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 4200,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'PULASKI RD',
#   'BEAT_OF_OCCURRENCE': 1722.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 20,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.957389412,
#   'LONGITUDE': -87.72787272,
#   'LOCATION': 'POINT (-87.727872720086 41.957389412248)'},
#  'JC113495': {'RD_NO': 'JC113495',
#   'CRASH_DATE': '01/11/2019 08:15:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE SAME DIRECTION',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN (NOT RAISED)',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 09:30:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 4400,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'PULASKI RD',
#   'BEAT_OF_OCCURRENCE': 815.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 4.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 20,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.813271598,
#   'LONGITUDE': -87.723935214,
#   'LOCATION': 'POINT (-87.723935214329 41.813271598175)'},
#  'JC113417': {'RD_NO': 'JC113417',
#   'CRASH_DATE': '01/11/2019 07:49:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'STOP SIGN/FLASHER',
#   'DEVICE_CONDITION': 'OTHER',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'OTHER',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:50:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 6229,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'BRYN MAWR AVE',
#   'BEAT_OF_OCCURRENCE': 1622.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.982795165,
#   'LONGITUDE': -87.784114099,
#   'LOCATION': 'POINT (-87.784114099444 41.982795164835)'},
#  'JC113432': {'RD_NO': 'JC113432',
#   'CRASH_DATE': '01/11/2019 07:45:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:49:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 2617,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'CERMAK RD',
#   'BEAT_OF_OCCURRENCE': 1034.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'INCAPACITATING INJURY',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 1.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 0.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.851849723,
#   'LONGITUDE': -87.691271882,
#   'LOCATION': 'POINT (-87.691271881535 41.851849723062)'},
#  'JC113419': {'RD_NO': 'JC113419',
#   'CRASH_DATE': '01/11/2019 07:45:00 PM',
#   'POSTED_SPEED_LIMIT': 5,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'UNKNOWN',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 08:10:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 2323,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'MADISON ST',
#   'BEAT_OF_OCCURRENCE': 1223.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.88107532,
#   'LONGITUDE': -87.684924091,
#   'LOCATION': 'POINT (-87.684924091188 41.881075320384)'},
#  'JC113409': {'RD_NO': 'JC113409',
#   'CRASH_DATE': '01/11/2019 07:44:00 PM',
#   'POSTED_SPEED_LIMIT': 15,
#   'TRAFFIC_CONTROL_DEVICE': 'OTHER',
#   'DEVICE_CONDITION': 'OTHER',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:48:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER BACKING',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 2750,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': '15TH PL',
#   'BEAT_OF_OCCURRENCE': 1023.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.86024819,
#   'LONGITUDE': -87.695287999,
#   'LOCATION': 'POINT (-87.695287998589 41.860248190286)'},
#  'JC113436': {'RD_NO': 'JC113436',
#   'CRASH_DATE': '01/11/2019 07:30:00 PM',
#   'POSTED_SPEED_LIMIT': 15,
#   'TRAFFIC_CONTROL_DEVICE': 'UNKNOWN',
#   'DEVICE_CONDITION': 'UNKNOWN',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'ONE-WAY',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:37:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 3802,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'WELLINGTON AVE',
#   'BEAT_OF_OCCURRENCE': 2523.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.935591506,
#   'LONGITUDE': -87.72233026,
#   'LOCATION': 'POINT (-87.72233025997 41.935591506448)'},
#  'JC113416': {'RD_NO': 'JC113416',
#   'CRASH_DATE': '01/11/2019 07:30:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DUSK',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:58:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 4100,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': '63RD ST',
#   'BEAT_OF_OCCURRENCE': 813.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NONINCAPACITATING INJURY',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 1.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.778737748,
#   'LONGITUDE': -87.725266786,
#   'LOCATION': 'POINT (-87.725266785648 41.778737748083)'},
#  'JC113398': {'RD_NO': 'JC113398',
#   'CRASH_DATE': '01/11/2019 07:30:00 PM',
#   'POSTED_SPEED_LIMIT': 15,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:35:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER OVERTAKING/PASSING',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 7447,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'SOUTH SHORE DR',
#   'BEAT_OF_OCCURRENCE': 334.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.761305471,
#   'LONGITUDE': -87.557705515,
#   'LOCATION': 'POINT (-87.557705515311 41.761305471394)'},
#  'JC113425': {'RD_NO': 'JC113425',
#   'CRASH_DATE': '01/11/2019 07:18:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 08:00:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 2901,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'ASHLAND AVE',
#   'BEAT_OF_OCCURRENCE': 1932.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.934275774,
#   'LONGITUDE': -87.668316452,
#   'LOCATION': 'POINT (-87.66831645216 41.934275774014)'},
#  'JC113394': {'RD_NO': 'JC113394',
#   'CRASH_DATE': '01/11/2019 07:15:00 PM',
#   'POSTED_SPEED_LIMIT': 25,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'ALLEY',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:34:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'FAILING TO REDUCE SPEED TO AVOID CRASH',
#   'STREET_NO': 1206,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'LARAMIE AVE',
#   'BEAT_OF_OCCURRENCE': 2532.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.902496564,
#   'LONGITUDE': -87.755926709,
#   'LOCATION': 'POINT (-87.755926708867 41.902496563795)'},
#  'JC113392': {'RD_NO': 'JC113392',
#   'CRASH_DATE': '01/11/2019 07:15:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'STOP SIGN/FLASHER',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:19:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 4099,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'CALIFORNIA AVE',
#   'BEAT_OF_OCCURRENCE': 1724.0,
#   'NUM_UNITS': 4.0,
#   'MOST_SEVERE_INJURY': 'REPORTED, NOT EVIDENT',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 1.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.955697653,
#   'LONGITUDE': -87.698145286,
#   'LOCATION': 'POINT (-87.698145286144 41.95569765302)'},
#  'JC113400': {'RD_NO': 'JC113400',
#   'CRASH_DATE': '01/11/2019 07:11:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN (NOT RAISED)',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:20:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 6700,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'GRAND AVE',
#   'BEAT_OF_OCCURRENCE': 2512.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.923727862,
#   'LONGITUDE': -87.792846825,
#   'LOCATION': 'POINT (-87.792846824949 41.923727861862)'},
#  'JC113437': {'RD_NO': 'JC113437',
#   'CRASH_DATE': '01/11/2019 07:10:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 08:20:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 742,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'HOMAN AVE',
#   'BEAT_OF_OCCURRENCE': 1121.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.894957945,
#   'LONGITUDE': -87.711566511,
#   'LOCATION': 'POINT (-87.711566511349 41.894957944562)'},
#  'JC113372': {'RD_NO': 'JC113372',
#   'CRASH_DATE': '01/11/2019 07:10:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:10:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 1,
#   'STREET_DIRECTION': 'E',
#   'STREET_NAME': '63RD ST',
#   'BEAT_OF_OCCURRENCE': 312.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.779949105,
#   'LONGITUDE': -87.625289553,
#   'LOCATION': 'POINT (-87.625289553338 41.779949104569)'},
#  'JC113370': {'RD_NO': 'JC113370',
#   'CRASH_DATE': '01/11/2019 07:10:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:20:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'DISREGARDING TRAFFIC SIGNALS',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 1700,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'JACKSON BLVD',
#   'BEAT_OF_OCCURRENCE': 1231.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 4.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.877694016,
#   'LONGITUDE': -87.669225537,
#   'LOCATION': 'POINT (-87.669225536826 41.87769401626)'},
#  'JC113376': {'RD_NO': 'JC113376',
#   'CRASH_DATE': '01/11/2019 07:08:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:29:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#   'SEC_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'STREET_NO': 4040,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'ARCHER AVE',
#   'BEAT_OF_OCCURRENCE': 921.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 4.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.820316832,
#   'LONGITUDE': -87.694320112,
#   'LOCATION': 'POINT (-87.694320111959 41.820316832262)'},
#  'JC113366': {'RD_NO': 'JC113366',
#   'CRASH_DATE': '01/11/2019 07:06:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'PEDESTRIAN',
#   'TRAFFICWAY_TYPE': 'ONE-WAY',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:07:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 3159,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'WARREN BLVD',
#   'BEAT_OF_OCCURRENCE': 1222.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NONINCAPACITATING INJURY',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 1.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.881777737,
#   'LONGITUDE': -87.706016144,
#   'LOCATION': 'POINT (-87.706016143852 41.881777737363)'},
#  'JC113368': {'RD_NO': 'JC113368',
#   'CRASH_DATE': '01/11/2019 07:05:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'CENTER TURN LANE',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:05:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER LANE USAGE',
#   'SEC_CONTRIBUTORY_CAUSE': 'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#   'STREET_NO': 1959,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'HALSTED ST',
#   'BEAT_OF_OCCURRENCE': 1813.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.917653401,
#   'LONGITUDE': -87.648339667,
#   'LOCATION': 'POINT (-87.648339666854 41.917653400726)'},
#  'JC113367': {'RD_NO': 'JC113367',
#   'CRASH_DATE': '01/11/2019 07:05:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:11:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 2829,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'KEDZIE AVE',
#   'BEAT_OF_OCCURRENCE': 1033.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 4.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 19,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.840036934,
#   'LONGITUDE': -87.704758798,
#   'LOCATION': 'POINT (-87.704758797752 41.840036934321)'},
#  'JC113377': {'RD_NO': 'JC113377',
#   'CRASH_DATE': '01/11/2019 06:45:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'FIXED OBJECT',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:30:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#   'SEC_CONTRIBUTORY_CAUSE': 'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#   'STREET_NO': 501,
#   'STREET_DIRECTION': 'E',
#   'STREET_NAME': '90TH ST',
#   'BEAT_OF_OCCURRENCE': 633.0,
#   'NUM_UNITS': 1.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 18,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.730954795,
#   'LONGITUDE': -87.611834374,
#   'LOCATION': 'POINT (-87.611834374146 41.730954794731)'},
#  'JC113352': {'RD_NO': 'JC113352',
#   'CRASH_DATE': '01/11/2019 06:45:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLOUDY/OVERCAST',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN BARRIER',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:10:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 6972,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'STONY ISLAND AVE',
#   'BEAT_OF_OCCURRENCE': 332.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 18,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.767922875,
#   'LONGITUDE': -87.586517864,
#   'LOCATION': 'POINT (-87.58651786409 41.767922874782)'},
#  'JC113345': {'RD_NO': 'JC113345',
#   'CRASH_DATE': '01/11/2019 06:45:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'FIXED OBJECT',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'WORN SURFACE',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 06:52:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER BACKING',
#   'SEC_CONTRIBUTORY_CAUSE': 'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#   'STREET_NO': 2001,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'MARQUETTE RD',
#   'BEAT_OF_OCCURRENCE': 726.0,
#   'NUM_UNITS': 1.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 18,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.771966056,
#   'LONGITUDE': -87.673771778,
#   'LOCATION': 'POINT (-87.673771777929 41.77196605569)'},
#  'JC113337': {'RD_NO': 'JC113337',
#   'CRASH_DATE': '01/11/2019 06:39:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN BARRIER',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 06:43:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO REDUCE SPEED TO AVOID CRASH',
#   'SEC_CONTRIBUTORY_CAUSE': 'IMPROPER LANE USAGE',
#   'STREET_NO': 2939,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'STATE ST',
#   'BEAT_OF_OCCURRENCE': 133.0,
#   'NUM_UNITS': 4.0,
#   'MOST_SEVERE_INJURY': 'NONINCAPACITATING INJURY',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 1.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 0.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 18,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.840780999,
#   'LONGITUDE': -87.626488447,
#   'LOCATION': 'POINT (-87.62648844682 41.840780998729)'},
#  'JC113347': {'RD_NO': 'JC113347',
#   'CRASH_DATE': '01/11/2019 06:32:00 PM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'STOP SIGN/FLASHER',
#   'DEVICE_CONDITION': 'UNKNOWN',
#   'WEATHER_CONDITION': 'UNKNOWN',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'CURVE, LEVEL',
#   'ROADWAY_SURFACE_COND': 'UNKNOWN',
#   'ROAD_DEFECT': 'WORN SURFACE',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 06:50:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO REDUCE SPEED TO AVOID CRASH',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 11500,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'BISHOP FORD EXPY IB',
#   'BEAT_OF_OCCURRENCE': 532.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 18,
#   'CRASH_DAY_OF_WEEK': 6,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.686124081,
#   'LONGITUDE': -87.601554719,
#   'LOCATION': 'POINT (-87.601554718911 41.686124080883)'},
#  'JC113350': {'RD_NO': 'JC113350',
#   'CRASH_DATE': '01/11/2019 06:30:00 PM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DARKNESS, LIGHTED ROAD',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/11/2019 07:10:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 6959,
#   'STREET_DIRECTION': 'W',
# ...
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 11:11:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 6401,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'KARLOV AVE',
#   'BEAT_OF_OCCURRENCE': 813.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.77671672,
#   'LONGITUDE': -87.72500612,
#   'LOCATION': 'POINT (-87.725006120317 41.776716720193)'},
#  'JC107745': {'RD_NO': 'JC107745',
#   'CRASH_DATE': '01/07/2019 10:40:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'ONE-WAY',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 10:44:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 6515,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'ARTESIAN AVE',
#   'BEAT_OF_OCCURRENCE': 832.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.775114865,
#   'LONGITUDE': -87.684603397,
#   'LOCATION': 'POINT (-87.684603397282 41.775114864541)'},
#  'JC107747': {'RD_NO': 'JC107747',
#   'CRASH_DATE': '01/07/2019 10:35:00 AM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE OPPOSITE DIRECTION',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN (NOT RAISED)',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 10:35:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'IMPROPER LANE USAGE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 3400,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'WILSON AVE',
#   'BEAT_OF_OCCURRENCE': 1723.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.964826901,
#   'LONGITUDE': -87.713258186,
#   'LOCATION': 'POINT (-87.713258186005 41.964826900885)'},
#  'JC109114': {'RD_NO': 'JC109114',
#   'CRASH_DATE': '01/07/2019 10:30:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'UNKNOWN',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE SAME DIRECTION',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/08/2019 11:15:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 1,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'LA SALLE ST',
#   'BEAT_OF_OCCURRENCE': 122.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.881990074,
#   'LONGITUDE': -87.632212876,
#   'LOCATION': 'POINT (-87.632212875914 41.881990073783)'},
#  'JC107841': {'RD_NO': 'JC107841',
#   'CRASH_DATE': '01/07/2019 10:30:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 11:44:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'FAILING TO REDUCE SPEED TO AVOID CRASH',
#   'STREET_NO': 8700,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'HALSTED ST',
#   'BEAT_OF_OCCURRENCE': 2223.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 3.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.735785266,
#   'LONGITUDE': -87.64375883,
#   'LOCATION': 'POINT (-87.643758829628 41.735785266472)'},
#  'JC107823': {'RD_NO': 'JC107823',
#   'CRASH_DATE': '01/07/2019 10:30:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'PARKED MOTOR VEHICLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 11:38:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 305,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'KILBOURN AVE',
#   'BEAT_OF_OCCURRENCE': 1113.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.885537945,
#   'LONGITUDE': -87.737941731,
#   'LOCATION': 'POINT (-87.737941731301 41.885537944615)'},
#  'JC107806': {'RD_NO': 'JC107806',
#   'CRASH_DATE': '01/07/2019 10:30:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 11:14:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'DISREGARDING TRAFFIC SIGNALS',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 4699,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'LA SALLE ST',
#   'BEAT_OF_OCCURRENCE': 215.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.809158319,
#   'LONGITUDE': -87.630717163,
#   'LOCATION': 'POINT (-87.630717163121 41.809158319278)'},
#  'JC107850': {'RD_NO': 'JC107850',
#   'CRASH_DATE': '01/07/2019 10:15:00 AM',
#   'POSTED_SPEED_LIMIT': 35,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'ANGLE',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 11:50:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'SEC_CONTRIBUTORY_CAUSE': 'NOT APPLICABLE',
#   'STREET_NO': 3700,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'ASHLAND AVE',
#   'BEAT_OF_OCCURRENCE': 912.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.826821149,
#   'LONGITUDE': -87.665627882,
#   'LOCATION': 'POINT (-87.665627881585 41.826821149303)'},
#  'JC107775': {'RD_NO': 'JC107775',
#   'CRASH_DATE': '01/07/2019 10:15:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN (NOT RAISED)',
#   'ALIGNMENT': 'STRAIGHT ON GRADE',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 10:23:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'EXCEEDING SAFE SPEED FOR CONDITIONS',
#   'SEC_CONTRIBUTORY_CAUSE': 'WEATHER',
#   'STREET_NO': 2855,
#   'STREET_DIRECTION': 'S',
#   'STREET_NAME': 'DAMEN AVE',
#   'BEAT_OF_OCCURRENCE': 912.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.840356249,
#   'LONGITUDE': -87.675264551,
#   'LOCATION': 'POINT (-87.675264551203 41.840356249274)'},
#  'JC107716': {'RD_NO': 'JC107716',
#   'CRASH_DATE': '01/07/2019 10:15:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'TRAFFIC SIGNAL',
#   'DEVICE_CONDITION': 'FUNCTIONING PROPERLY',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'REAR END',
#   'TRAFFICWAY_TYPE': 'NOT DIVIDED',
#   'ALIGNMENT': 'STRAIGHT ON GRADE',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'OTHER',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 10:15:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FOLLOWING TOO CLOSELY',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 4801,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'LAWRENCE AVE',
#   'BEAT_OF_OCCURRENCE': 1623.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'REPORTED, NOT EVIDENT',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 1.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.967913455,
#   'LONGITUDE': -87.748048773,
#   'LOCATION': 'POINT (-87.748048773425 41.967913455117)'},
#  'JC107702': {'RD_NO': 'JC107702',
#   'CRASH_DATE': '01/07/2019 10:05:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'PEDESTRIAN',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN (NOT RAISED)',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 10:10:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'UNABLE TO DETERMINE',
#   'STREET_NO': 2400,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': '53RD ST',
#   'BEAT_OF_OCCURRENCE': 923.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NONINCAPACITATING INJURY',
#   'INJURIES_TOTAL': 1.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 1.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 1.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.797619505,
#   'LONGITUDE': -87.684165396,
#   'LOCATION': 'POINT (-87.684165396419 41.797619504824)'},
#  'JC107715': {'RD_NO': 'JC107715',
#   'CRASH_DATE': '01/07/2019 10:01:00 AM',
#   'POSTED_SPEED_LIMIT': 30,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'RAIN',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'TURNING',
#   'TRAFFICWAY_TYPE': 'DIVIDED - W/MEDIAN (NOT RAISED)',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'WET',
#   'ROAD_DEFECT': 'NO DEFECTS',
#   'REPORT_TYPE': 'ON SCENE',
#   'CRASH_TYPE': 'NO INJURY / DRIVE AWAY',
#   'DATE_POLICE_NOTIFIED': '01/07/2019 10:01:00 AM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'IMPROPER BACKING',
#   'STREET_NO': 4898,
#   'STREET_DIRECTION': 'N',
#   'STREET_NAME': 'CICERO AVE',
#   'BEAT_OF_OCCURRENCE': 1623.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.969839753,
#   'LONGITUDE': -87.748004139,
#   'LOCATION': 'POINT (-87.748004139037 41.969839752885)'},
#  'JC109277': {'RD_NO': 'JC109277',
#   'CRASH_DATE': '01/07/2019 10:00:00 AM',
#   'POSTED_SPEED_LIMIT': 10,
#   'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
#   'DEVICE_CONDITION': 'NO CONTROLS',
#   'WEATHER_CONDITION': 'CLEAR',
#   'LIGHTING_CONDITION': 'DAYLIGHT',
#   'FIRST_CRASH_TYPE': 'SIDESWIPE OPPOSITE DIRECTION',
#   'TRAFFICWAY_TYPE': 'PARKING LOT',
#   'ALIGNMENT': 'STRAIGHT AND LEVEL',
#   'ROADWAY_SURFACE_COND': 'DRY',
#   'ROAD_DEFECT': 'UNKNOWN',
#   'REPORT_TYPE': 'NOT ON SCENE (DESK REPORT)',
#   'CRASH_TYPE': 'INJURY AND / OR TOW DUE TO CRASH',
#   'DATE_POLICE_NOTIFIED': '01/08/2019 01:29:00 PM',
#   'PRIM_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'SEC_CONTRIBUTORY_CAUSE': 'FAILING TO YIELD RIGHT-OF-WAY',
#   'STREET_NO': 2050,
#   'STREET_DIRECTION': 'W',
#   'STREET_NAME': 'TAYLOR ST',
#   'BEAT_OF_OCCURRENCE': 1225.0,
#   'NUM_UNITS': 2.0,
#   'MOST_SEVERE_INJURY': 'NO INDICATION OF INJURY',
#   'INJURIES_TOTAL': 0.0,
#   'INJURIES_FATAL': 0.0,
#   'INJURIES_INCAPACITATING': 0.0,
#   'INJURIES_NON_INCAPACITATING': 0.0,
#   'INJURIES_REPORTED_NOT_EVIDENT': 0.0,
#   'INJURIES_NO_INDICATION': 2.0,
#   'INJURIES_UNKNOWN': 0.0,
#   'CRASH_HOUR': 10,
#   'CRASH_DAY_OF_WEEK': 2,
#   'CRASH_MONTH': 1,
#   'LATITUDE': 41.8691913,
#   'LONGITUDE': -87.678024944,
#   'LOCATION': 'POINT (-87.678024943909 41.869191300095)'},
#  ...}

# %% [markdown]
# adding geospatial missing data

# %%
def query_api(queries, resultDict):
    # Initialize the geocoder with the API key
    geocoder = OpenCageGeocode(get_api_key())

    # Iterate over each query in the provided list
    for query in queries:
        # Check if the query has already been processed
        if query not in resultDict:
            try:
                # Attempt to geocode the query
                results = geocoder.geocode(query)
                # If results are found, extract latitude and longitude
                if results:
                    resultDict[query]= {
                        "lat": results[0]['geometry']['lat'],
                        "lng": results[0]['geometry']['lng'],
                    }
                else:
                    # Log if no results were found for the query
                    print(f"No results found for query: {query}")
            except Exception as e:
                # Log any errors that occur during the geocoding process
                print(f"Error geocoding query '{query}': {e}")
            # Sleep for 1 second to avoid hitting the API rate limit
            time.sleep(1)
    
    # Return the updated result dictionary with geocoded data
    return resultDict

# %%
def create_file_with_missing_location_values(crashes_df, results_file="missing lat lng python.json"):
    # Ensure the results file exists or create it if it doesn't
    check_if_file_exists_and_create(results_file)
    
    try:
        # Attempt to open and read the existing results file
        with open(results_file) as f:
            resultDict = json.load(f)  # Load the JSON data into a dictionary
    except FileNotFoundError:
        # If the file does not exist, initialize an empty dictionary
        resultDict = {}
    except json.JSONDecodeError as e:
        # Handle JSON decoding errors (e.g., if the file is corrupted)
        print(f"Error decoding JSON from file '{results_file}': {e}")
        resultDict = {}  # Reset to an empty dictionary
    except Exception as e:
        # Handle any other unexpected exceptions that may occur
        print(f"Unexpected error while reading '{results_file}': {e}")
        resultDict = {}  # Reset to an empty dictionary

    # Create a set of queries based on the STREET_NAME and STREET_NO from the crashes DataFrame
    queries = {f"{row['STREET_NAME']} {row['STREET_NO']}, Chicago, Illinois" for row in crashes_df.values()}

    try:
        # Call the query_api function to get geocoded data for the queries
        resultDict = query_api(queries, resultDict)
    except Exception as e:
        # Handle errors that may occur during the API query
        print(f"Error during API query: {e}")

    try:
        # Attempt to write the updated result dictionary back to the results file
        with open(results_file, 'w') as f:
            json.dump(resultDict, f)  # Save the dictionary as JSON
    except Exception as e:
        # Handle errors that may occur while writing to the file
        print(f"Error writing to file '{results_file}': {e}")

# %%
create_file_with_missing_location_values(crashes_df)

# %%
coiao

# %% [markdown]
# adding delta between car crash and police report

# %%
def add_delta_car_crash_date_police_report_date (crashes_df):
    # Define the date format for parsing
    date_format = "%m/%d/%Y %I:%M:%S %p"
    
    # Iterate over each item in the crashes DataFrame
    for _, v in crashes_df.items():
        try: 
            # Parse the crash date from the DataFrame
            crash_date = datetime.strptime(v['CRASH_DATE'], date_format)
            # Parse the date when police were notified
            date_police_notified = datetime.strptime(v['DATE_POLICE_NOTIFIED'], date_format)

            # Calculate the time difference between the two dates
            delta = date_police_notified - crash_date

            # Store the delta time in a formatted string in the DataFrame
            v['DELTA_TIME_CRASH_DATE_POLICE_REPORT_DATE'] = f"{delta.days} days, {delta.seconds // 3600} hours, {(delta.seconds // 60) % 60} minutes, {delta.seconds % 60} seconds" 
        except KeyError as e:
            # Handle cases where expected keys might be missing
            print(f'KeyError for key {v.get("RD_NO", "unknown")}: {e}')  
        except ValueError as e:
            # Handle cases where the date format is invalid
            print(f'ValueError for key {v.get("RD_NO", "unknown")}: {e}')  
        except Exception as e:
            # Handle any other unexpected exceptions
            print(f'Unexpected error for key {v.get("RD_NO", "unknown")}: {e}')  
    
    # Return the modified DataFrame with the added delta time
    return crashes_df

# %% [markdown]
# fixing wrong licens plates

# %%
def fix_license_plates(dict_df):
    # Define a regex pattern for valid license plates
    license_plates_pattern = r'^[A-Z]{2}\d{6}$'
    
    # Initialize a new dictionary to store modified entries
    modified_dict = {}

    # Iterate over each key-value pair in the input dictionary
    for k, v in dict_df.items():
        try:  # Start of exception handling
            # Check if the key does not match the license plate pattern
            if not re.match(license_plates_pattern, k):
                # Convert the 'RD_NO' value to uppercase
                v['RD_NO'] = v['RD_NO'].upper()  
                # Add the modified entry to the new dictionary with the key in uppercase
                modified_dict[k.upper()] = v 
            else:
                # If the key matches the pattern, add it unchanged to the new dictionary
                modified_dict[k] = v 
        except KeyError as e:
            # Handle cases where expected keys might be missing
            print(f'KeyError for key {k}: {e}')  
        except Exception as e:
            # Handle any other unexpected exceptions
            print(f'Unexpected error for key {k}: {e}')  

    # Return the modified dictionary with updated license plates
    return modified_dict

# %% [markdown]
# conversion of the float64 columns to int when there is no need for it to be a float

# %%
def convert_float_columns_to_int_columns(dict_df, columns_to_convert = [
    'NUM_UNITS',
    'INJURIES_TOTAL',
    'INJURIES_FATAL',
    'INJURIES_INCAPACITATING',
    'INJURIES_NON_INCAPACITATING',
    'INJURIES_REPORTED_NOT_EVIDENT',
    'INJURIES_NO_INDICATION',
    'INJURIES_UNKNOWN'
]):
    # Iterate over each key-value pair in the input dictionary
    for k, v in dict_df.items():
        # Iterate over each column specified for conversion
        for col in columns_to_convert:
            # Get the value for the current column
            value = v.get(col)
            # Check if the value is a float
            if isinstance(value, float):
                # Convert float to int and update the dictionary
                dict_df[k][col] = int(value)
            # Check if the value is a string
            elif isinstance(value, str):
                try:
                    # Attempt to convert the string to a float, then to an int
                    dict_df[k][col] = int(float(value))
                except (ValueError, TypeError) as e:
                    # Print an error message if conversion fails
                    print(f'Error converting column {col} for key {k}: {e}')
            else:
                # Print a message for unexpected data types
                print(f'Unexpected type for column {col} in key {k}: {type(value)}')

    # Return the modified dictionary with converted columns
    return dict_df

# %% [markdown]
# main

# %%
crashes_df = fix_license_plates(crashes_df)
crashes_df = convert_float_columns_to_int_columns(crashes_df)
crashes_df = add_delta_car_crash_date_police_report_date(crashes_df)
